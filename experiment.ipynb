# %%
import warnings
warnings.filterwarnings("ignore")
# warnings.filterwarnings("ignore", category=FutureWarning, module="torch")

import torch
torch.cuda.empty_cache()

import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.environ["TOKENIZERS_PARALLELISM"] = "False"
os.environ["VLLM_TORCH_COMPILE_CACHE"] = "/projects/aiwell/conda/envs/ToM/.cache/"
os.environ["HF_HOME"] = "/projects/aiwell/conda/envs/ToM/.cache/"
os.environ["HUGGINGFACE_HUB_CACHE"] = "/projects/aiwell/conda/envs/ToM/.cache/"


from runner import run_benchmark

run_benchmark(
    dataset = 'msed',
    model_name= 'qwen',
    experiment_type= 'expt1',
    batch_size= 20
)
# Out:
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.38it/s]
# Processing with...
#   0%|          | 0/2 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k', 'output_logits']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|██████████| 2/2 [00:20<00:00, 10.18s/it]
# Processing time: 20.37 seconds
